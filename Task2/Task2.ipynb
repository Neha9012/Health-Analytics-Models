# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('train.csv')  # Replace with the actual file path

# Display the first few rows of the dataset
print(data.head())

# Check for missing values
print(data.isnull().sum())

# Check the column names
print(data.columns)
# Out:
#    time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# 0                14                  41               0               11
# 1                 2                  30               0               12
# 2                 5                  66               0               22
# 3                 3                  63               0                8
# 4                 5                  40               0                6
#
#    number_outpatient  number_emergency  number_inpatient  number_diagnoses  \
# 0                  0                 0                 0                 6
# 1                  0                 0                 1                 9
# 2                  1                 0                 2                 9
# 3                  0                 0                 0                 8
# 4                  0                 0                 1                 9
#
#    race_Caucasian  race_AfricanAmerican  ...  citoglipton_No  insulin_No  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

# Select numerical columns for scaling
numerical_cols = ['time_in_hospital', 'num_lab_procedures', 'num_procedures',
                  'num_medications', 'number_outpatient', 'number_emergency',
                  'number_inpatient', 'number_diagnoses']

# Initialize the scaler
scaler = StandardScaler()

# Apply scaling to the numerical columns
data[numerical_cols] = scaler.fit_transform(data[numerical_cols])

# Verify the scaling
print(data[numerical_cols].head())
# Out:
#    time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# 0          3.210974           -0.099154        -0.78639        -0.615281
# 1         -0.800921           -0.655597        -0.78639        -0.491940
# 2          0.202052            1.165490        -0.78639         0.741474
# 3         -0.466597            1.013732        -0.78639        -0.985305
# 4          0.202052           -0.149740        -0.78639        -1.231988
#
#    number_outpatient  number_emergency  number_inpatient  number_diagnoses
# 0          -0.298858         -0.206805         -0.509172         -0.731704
# 1          -0.298858         -0.206805          0.282697          0.813976
# 2           0.517872         -0.206805          1.074567          0.813976
# 3          -0.298858         -0.206805         -0.509172          0.298749
# 4          -0.298858         -0.206805          0.282697          0.813976

# %%
pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
print(df.columns)
# Out:
# Index(['time_in_hospital', 'num_lab_procedures', 'num_procedures',
#        'num_medications', 'number_outpatient', 'number_emergency',
#        'number_inpatient', 'number_diagnoses', 'race_Caucasian',
#        'race_AfricanAmerican', 'gender_Female', 'age_[70-80)', 'age_[60-70)',
#        'age_[50-60)', 'age_[80-90)', 'age_[40-50)', 'payer_code_?',
#        'payer_code_MC', 'payer_code_HM', 'payer_code_SP', 'payer_code_BC',
#        'medical_specialty_?', 'medical_specialty_InternalMedicine',
#        'medical_specialty_Emergency/Trauma',
#        'medical_specialty_Family/GeneralPractice',
#        'medical_specialty_Cardiology', 'diag_1_428', 'diag_1_414',
#        'diag_1_786', 'diag_2_276', 'diag_2_428', 'diag_2_250', 'diag_2_427',
#        'diag_3_250', 'diag_3_401', 'diag_3_276', 'diag_3_428',
#        'max_glu_serum_None', 'A1Cresult_None', 'metformin_No',
#        'repaglinide_No', 'nateglinide_No', 'chlorpropamide_No',
# ...

# %%
# Separate features and targets
X = df.drop(columns=['readmitted'])  # Features excluding readmitted
y_readmission = df['readmitted']  # Readmission target variable
y_disease = df['diag_1_428']  # Example disease target variable (modify as needed)

# Handle missing values and scale numerical features
imputer = SimpleImputer(strategy='most_frequent')
X_imputed = imputer.fit_transform(X)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_imputed)

# Split the data into training and testing sets for both tasks
X_train, X_test, y_disease_train, y_disease_test, y_readmission_train, y_readmission_test = train_test_split(
    X_scaled, y_disease, y_readmission, test_size=0.3, random_state=42
)

# Define models
models = {
    'Logistic Regression': LogisticRegression(),
    'Random Forest': RandomForestClassifier(),
    'XGBoost': XGBClassifier()
}

# Train and evaluate models for Disease Prediction
print("Disease Prediction Results:")
for model_name, model in models.items():
    model.fit(X_train, y_disease_train)
    y_disease_pred = model.predict(X_test)
    accuracy = accuracy_score(y_disease_test, y_disease_pred)
    print(f"\n{model_name} - Disease Prediction Accuracy: {accuracy}")
    print(classification_report(y_disease_test, y_disease_pred))

# Train and evaluate models for Readmission Prediction
print("\nReadmission Prediction Results:")
for model_name, model in models.items():
    model.fit(X_train, y_readmission_train)
    y_readmission_pred = model.predict(X_test)
    accuracy = accuracy_score(y_readmission_test, y_readmission_pred)
    print(f"\n{model_name} - Readmission Prediction Accuracy: {accuracy}")
    print(classification_report(y_readmission_test, y_readmission_pred))
# Out:
# Disease Prediction Results:
#
# Logistic Regression - Disease Prediction Accuracy: 1.0
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      7006
#         True       1.00      1.00      1.00       494
#
#     accuracy                           1.00      7500
#    macro avg       1.00      1.00      1.00      7500
# weighted avg       1.00      1.00      1.00      7500
#
#
# Random Forest - Disease Prediction Accuracy: 1.0
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      7006
#         True       1.00      1.00      1.00       494
#
#     accuracy                           1.00      7500
#    macro avg       1.00      1.00      1.00      7500
# weighted avg       1.00      1.00      1.00      7500
#
#
# XGBoost - Disease Prediction Accuracy: 1.0
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      7006
# ...

# %%
print(df.columns)
# Out:
# Index(['time_in_hospital', 'num_lab_procedures', 'num_procedures',
#        'num_medications', 'number_outpatient', 'number_emergency',
#        'number_inpatient', 'number_diagnoses', 'race_Caucasian',
#        'race_AfricanAmerican', 'gender_Female', 'age_[70-80)', 'age_[60-70)',
#        'age_[50-60)', 'age_[80-90)', 'age_[40-50)', 'payer_code_?',
#        'payer_code_MC', 'payer_code_HM', 'payer_code_SP', 'payer_code_BC',
#        'medical_specialty_?', 'medical_specialty_InternalMedicine',
#        'medical_specialty_Emergency/Trauma',
#        'medical_specialty_Family/GeneralPractice',
#        'medical_specialty_Cardiology', 'diag_1_428', 'diag_1_414',
#        'diag_1_786', 'diag_2_276', 'diag_2_428', 'diag_2_250', 'diag_2_427',
#        'diag_3_250', 'diag_3_401', 'diag_3_276', 'diag_3_428',
#        'max_glu_serum_None', 'A1Cresult_None', 'metformin_No',
#        'repaglinide_No', 'nateglinide_No', 'chlorpropamide_No',
# ...

# %%
# Example: Using the 'num_lab_procedures' column to define disease risk
threshold = 10  # Define a threshold for disease risk, e.g., more than 10 lab procedures
df['disease_risk'] = (df['num_lab_procedures'] > threshold).astype(int)

# Now, you can proceed with the rest of the code
X = df.drop(columns=['disease_risk', 'readmitted'])  # Features
y_disease = df['disease_risk']  # Target for disease prediction
y_readmission = df['readmitted']  # Target for readmission prediction

# %%
print(df.columns)
print(df.head())  # Preview the first few rows of the dataset
# Out:
# Index(['time_in_hospital', 'num_lab_procedures', 'num_procedures',
#        'num_medications', 'number_outpatient', 'number_emergency',
#        'number_inpatient', 'number_diagnoses', 'race_Caucasian',
#        'race_AfricanAmerican', 'gender_Female', 'age_[70-80)', 'age_[60-70)',
#        'age_[50-60)', 'age_[80-90)', 'age_[40-50)', 'payer_code_?',
#        'payer_code_MC', 'payer_code_HM', 'payer_code_SP', 'payer_code_BC',
#        'medical_specialty_?', 'medical_specialty_InternalMedicine',
#        'medical_specialty_Emergency/Trauma',
#        'medical_specialty_Family/GeneralPractice',
#        'medical_specialty_Cardiology', 'diag_1_428', 'diag_1_414',
#        'diag_1_786', 'diag_2_276', 'diag_2_428', 'diag_2_250', 'diag_2_427',
#        'diag_3_250', 'diag_3_401', 'diag_3_276', 'diag_3_428',
#        'max_glu_serum_None', 'A1Cresult_None', 'metformin_No',
#        'repaglinide_No', 'nateglinide_No', 'chlorpropamide_No',
# ...

# %%
# Define the features and target variables
X = df.drop(columns=['disease_risk', 'readmitted'])  # Features (remove 'disease_risk' and 'readmitted' from X)
y_disease = df['disease_risk']  # Target for disease risk prediction
y_readmission = df['readmitted']  # Target for readmission prediction

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
X_train, X_test, y_train_disease, y_test_disease = train_test_split(X, y_disease, test_size=0.2, random_state=42)
X_train, X_test, y_train_readmission, y_test_readmission = train_test_split(X, y_readmission, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Logistic Regression for disease risk prediction
model_disease = LogisticRegression()
model_disease.fit(X_train, y_train_disease)

# Predicting and evaluating the model
y_pred_disease = model_disease.predict(X_test)
print(f"Disease Risk Prediction Accuracy: {accuracy_score(y_test_disease, y_pred_disease)}")
print(classification_report(y_test_disease, y_pred_disease))
# Out:
# Disease Risk Prediction Accuracy: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       390
#            1       1.00      1.00      1.00      4610
#
#     accuracy                           1.00      5000
#    macro avg       1.00      1.00      1.00      5000
# weighted avg       1.00      1.00      1.00      5000

# %%
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Step 1: Preprocessing

# Define the features (X) and target variables (y)
X = df.drop(columns=['disease_risk', 'readmitted'])  # Features for both models
y_disease = df['disease_risk']  # Target for disease risk prediction
y_readmission = df['readmitted']  # Target for readmission prediction

# Split the dataset into training and testing sets (80% training, 20% testing)
X_train, X_test, y_train_disease, y_test_disease = train_test_split(X, y_disease, test_size=0.2, random_state=42)
X_train, X_test, y_train_readmission, y_test_readmission = train_test_split(X, y_readmission, test_size=0.2, random_state=42)

# Step 2: Define preprocessing for both numeric and categorical features
numeric_features = X.select_dtypes(include=['int64', 'float64']).columns
categorical_features = X.select_dtypes(include=['object']).columns

# Preprocessing for numeric features (impute missing values, scale them)
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),  # Impute missing values with the mean
    ('scaler', StandardScaler())  # Scale numeric features
])

# Preprocessing for categorical features (impute missing values, one-hot encode them)
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),  # Impute missing values with 'missing'
    ('onehot', OneHotEncoder(handle_unknown='ignore'))  # One-hot encode categorical features
])

# Combine both transformers into a single column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ]
)

# Step 3: Create a model pipeline for disease risk prediction
pipeline_disease = Pipeline(steps=[
    ('preprocessor', preprocessor),  # Apply preprocessing
    ('classifier', RandomForestClassifier(n_estimators=100, random_state=42))  # Use RandomForestClassifier for prediction
])

# Train the model on the disease risk prediction data
pipeline_disease.fit(X_train, y_train_disease)

# Step 4: Predict disease risk on the test data and evaluate the model
y_pred_disease = pipeline_disease.predict(X_test)
print("Disease Risk Prediction - Accuracy:", accuracy_score(y_test_disease, y_pred_disease))
print(classification_report(y_test_disease, y_pred_disease))

# Step 5: Create a model pipeline for readmission prediction
pipeline_readmission = Pipeline(steps=[
    ('preprocessor', preprocessor),  # Apply preprocessing
    ('classifier', RandomForestClassifier(n_estimators=100, random_state=42))  # Use RandomForestClassifier for prediction
])

# Train the model on the readmission prediction data
pipeline_readmission.fit(X_train, y_train_readmission)

# Step 6: Predict readmission on the test data and evaluate the model
y_pred_readmission = pipeline_readmission.predict(X_test)
print("Readmission Prediction - Accuracy:", accuracy_score(y_test_readmission, y_pred_readmission))
print(classification_report(y_test_readmission, y_pred_readmission))
# Out:
# Disease Risk Prediction - Accuracy: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       390
#            1       1.00      1.00      1.00      4610
#
#     accuracy                           1.00      5000
#    macro avg       1.00      1.00      1.00      5000
# weighted avg       1.00      1.00      1.00      5000
#
# Readmission Prediction - Accuracy: 0.586
#               precision    recall  f1-score   support
#
#            0       0.61      0.65      0.63      2731
#            1       0.55      0.51      0.53      2269
#
#     accuracy                           0.59      5000
#    macro avg       0.58      0.58      0.58      5000
# weighted avg       0.58      0.59      0.58      5000
